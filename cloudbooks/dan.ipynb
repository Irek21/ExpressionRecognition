# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip DAN-main.zip

# %%
# !tar -xf gdrive/MyDrive/train_set.tar -C DAN/datasets/AffectNet/train_set
# !tar -xf gdrive/MyDrive/val_set.tar -C DAN/dataset/AffectNet/val_set

# %%
# !unzip gdrive/MyDrive/train_set.zip -d datasets/AffectNet/train_set
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: datasets/AffectNet/train_set/images/287596.jpg
#   inflating: datasets/AffectNet/train_set/images/319227.jpg
#   inflating: datasets/AffectNet/train_set/images/333403.jpg
#   inflating: datasets/AffectNet/train_set/images/191159.jpg
#   inflating: datasets/AffectNet/train_set/images/276107.jpg
#   inflating: datasets/AffectNet/train_set/images/271419.jpg
#   inflating: datasets/AffectNet/train_set/images/157033.jpg
#   inflating: datasets/AffectNet/train_set/images/105823.jpg
#   inflating: datasets/AffectNet/train_set/images/24556.jpg
#   inflating: datasets/AffectNet/train_set/images/201410.jpg
#   inflating: datasets/AffectNet/train_set/images/374707.jpg
#   inflating: datasets/AffectNet/train_set/images/72694.jpg
#   inflating: datasets/AffectNet/train_set/images/228441.jpg
#   inflating: datasets/AffectNet/train_set/images/295720.jpg
#   inflating: datasets/AffectNet/train_set/images/277643.jpg
# ...

# %%
# !unzip gdrive/MyDrive/val_set.zip -d datasets/AffectNet/val_set
# Out:
# Archive:  gdrive/MyDrive/val_set.zip
#    creating: datasets/AffectNet/val_set/images/
#   inflating: datasets/AffectNet/val_set/images/5265.jpg
#   inflating: datasets/AffectNet/val_set/images/518.jpg
#   inflating: datasets/AffectNet/val_set/images/1693.jpg
#   inflating: datasets/AffectNet/val_set/images/1118.jpg
#   inflating: datasets/AffectNet/val_set/images/1.jpg
#   inflating: datasets/AffectNet/val_set/images/985.jpg
#   inflating: datasets/AffectNet/val_set/images/2341.jpg
#   inflating: datasets/AffectNet/val_set/images/5475.jpg
#   inflating: datasets/AffectNet/val_set/images/3433.jpg
#   inflating: datasets/AffectNet/val_set/images/918.jpg
#   inflating: datasets/AffectNet/val_set/images/242.jpg
#   inflating: datasets/AffectNet/val_set/images/3334.jpg
#   inflating: datasets/AffectNet/val_set/images/4513.jpg
#   inflating: datasets/AffectNet/val_set/images/3217.jpg
#   inflating: datasets/AffectNet/val_set/images/1176.jpg
# ...

# %%
# !cp gdrive/MyDrive/resnet18_msceleb.pth models/resnet18_msceleb.pth

# %%
# !cp gdrive/MyDrive/affectnet.csv datasets/AffectNet/affectnet.csv

# %%
# !python3 utils/convert_affectnet.py
# Out:
# convert done.

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 affectnet.py --epochs 10 --num_class 8
# Out:
# Whole train set size: 287651
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Validation set size: 3999
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 affectnet.py --epochs 10 --num_class 8
# Out:
# Whole train set size: 287651
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Validation set size: 3999
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
